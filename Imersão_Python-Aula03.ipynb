# %% [markdown]
# Aula 02 - Importação

# %%
import pandas as pd
import plotly.express as px

# %%
df_principal = pd.read_excel('acoes.xlsx',sheet_name='Principal')
df_principal
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)  Var. Sem. (%)  Var. Mês (%)  \
# 0   USIM5 2024-01-26         9.50          5.20          11.76          2.26
# 1   CMIN3 2024-01-26         6.82          2.40           2.40        -12.11
# 2   PETR3 2024-01-26        41.96          2.19           7.73          7.64
# 3   SUZB3 2024-01-26        52.91          2.04           2.14         -4.89
# 4   CPFE3 2024-01-26        37.10          2.03           2.49         -3.66
# ..    ...        ...          ...           ...            ...           ...
# 76  CRFB3 2024-01-26        10.71         -2.45          -9.47        -13.98
# 77  BHIA3 2024-01-26         8.70         -2.46          -6.95        -23.55
# 78  RENT3 2024-01-26        56.24         -3.63          -6.41        -11.57
# 79  CVCB3 2024-01-26         3.07         -4.36          -5.54        -12.29
# 80  GOLL4 2024-01-26         5.92         -8.07         -15.91        -34.00
#
#     Var. Ano (%)  Var. 12M (%)  Val. Mín  Val. Máx  ...    Variação $  \
# 0           2.26         15.97      9.18      9.56  ...  2.418897e+08
# 1         -12.11         50.56      6.66      6.86  ...  1.775160e+08
# 2           7.64         77.55     40.81     42.34  ...  2.140059e+09
# 3          -4.89         18.85     51.89     53.17  ...  7.229463e+08
# 4          -3.66         20.70     36.37     37.32  ...  1.385740e+08
# ..           ...           ...       ...       ...  ...           ...
# 76        -13.98        -32.72     10.70     11.08  ... -1.436355e+08
# 77        -23.55        -85.74      8.67      8.95  ... -2.081024e+07
# 78        -11.57         -2.77     56.04     58.90  ... -1.807433e+09
# 79        -12.29        -36.83      3.05      3.23  ... -7.355741e+07
# 80        -34.00        -25.44      5.51      6.02  ... -1.029932e+08
#
#     Resultado   Nome da Empresa           Segmento  Idade  \
# 0       Subiu          Usiminas         Siderurgia     64
# 1       Subiu     CSN Mineração          Mineração     10
# 2       Subiu         Petrobras           Petróleo     68
# 3       Subiu            Suzano   Papel e Celulose     97
# 4       Subiu      CPFL Energia            Energia    108
# ..        ...               ...                ...    ...
# 76     Desceu  Carrefour Brasil             Varejo     48
# 77     Desceu       Casas Bahia             Varejo     64
# 78     Desceu          Localiza  Aluguel de Carros     50
# 79     Desceu               CVC            Turismo     49
# 80     Desceu               GOL   Transporte Aéreo     20
#
#               Cat_Idade Var. Semanal % Var. Ini. Semanal $  Resultado Sem.  \
# 0   Entre 50 e 100 anos         0.1176            8.500358    5.149330e+08
# 1      Menos de 50 anos         0.0240            6.660156    1.775160e+08
# 2   Entre 50 e 100 anos         0.0773           38.949225    7.165276e+09
# 3   Entre 50 e 100 anos         0.0214           51.801449    7.576423e+08
# 4      Mais de 100 anos         0.0249           36.198654    1.692121e+08
# ..                  ...            ...                 ...             ...
# 76     Menos de 50 anos        -0.0947           11.830332   -5.982470e+08
# 77  Entre 50 e 100 anos        -0.0695            9.349812   -6.163014e+07
# 78  Entre 50 e 100 anos        -0.0641           60.091890   -3.286442e+09
# 79     Menos de 50 anos        -0.0554            3.250053   -9.463272e+07
# 80     Menos de 50 anos        -0.1591            7.040076   -2.219822e+08
#
#    Resultado Sem..1
# 0             Subiu
# 1             Subiu
# 2             Subiu
# 3             Subiu
# 4             Subiu
# ..              ...
# 76           Desceu
# 77           Desceu
# 78           Desceu
# 79           Desceu
# 80           Desceu
#
# [81 rows x 24 columns]

# %%
df_total_de_acoes = pd.read_excel('acoes.xlsx',sheet_name='Total_de_acoes')
df_total_de_acoes
# Out:
#                       Código  Qtde. Teórica
# 0                      RRRP3   2.356656e+08
# 1                      ALOS3   5.326166e+08
# 2                      ALPA4   1.767340e+08
# 3                      ABEV3   4.394246e+09
# 4                      ARZZ3   6.230589e+07
# ..                       ...            ...
# 84                     VBBR3   1.114413e+09
# 85                     WEGE3   1.481593e+09
# 86                     YDUQ3   2.893479e+08
# 87  Quantidade Teórica Total   9.637210e+10
# 88                   Redutor   1.704785e+07
#
# [89 rows x 2 columns]

# %%
df_analises = pd.read_excel('acoes.xlsx',sheet_name='Análises')
df_analises
# Out:
#                        Maior    4762926995.24809              Unnamed: 2
# 0                      Menor  -1807432634.459543                     NaN
# 1                      Média     165190210.47934                     NaN
# 2        Média de quem subiu    448164250.230498                     NaN
# 3       Média de quem desceu   -181109141.751867                     NaN
# 4                        NaN                 NaN                     NaN
# 5                        NaN                 NaN                     NaN
# 6                        NaN                 NaN                     NaN
# 7                        NaN                 NaN                     NaN
# 8                   Segmento            Variação  Variação de quem subiu
# 9                 Siderurgia    489935930.928323        489935930.928323
# 10                 Mineração   4940442965.550434       4940442965.550434
# 11                  Petróleo   6093288832.262836       6093288832.262836
# 12          Papel e Celulose    722946282.709038        722946282.709038
# 13                   Energia    -20439929.552336        821116399.611279
# 14          Shopping Centers    117732680.078425        117732680.078425
# 15      Serviços Financeiros   2605851498.609887       3784169702.158992
# 16                     Saúde     60321469.882997         453917907.01324
# 17              Petroquímica     69054317.636039         69054317.636039
# 18          Transporte Aéreo    -37540997.063643           65452205.5528
# 19                  Educação     17822320.131763         72295838.986161
# 20                   Química    388705223.956018        388705223.956018
# 21          Construção Civil    -61087401.606068         37525872.377284
# 22                  Calçados     19895417.765127         41021792.090772
# 23                 Alimentos     407833683.09245         407833683.09245
# 24        Varejo Alimentício      6340916.223144          6340916.223144
# 25          Telecomunicações    292938114.423578        292938114.423578
# 26                 Logística    233902674.792574        233902674.792574
# 27                Tecnologia     24135955.514564         33667333.260539
# 28                   Holding    416092244.423763        416092244.423763
# 29       Varejo Farmacêutico    202352473.739829        202352473.739829
# 30                    Varejo   -800329983.839483         28493619.274395
# 31                   Bebidas                   0                       0
# 32         Saneamento Básico    -15725678.564115                       0
# 33    Equipamentos Elétricos   -118230410.439646                       0
# 34               Agronegócio    -88901449.421455                       0
# 35            Infraestrutura    -39743554.314915                       0
# 36                   Seguros    -21765343.021314                       0
# 37                Varejo Pet     -9242203.652013                       0
# 38              Aeroespacial   -233651943.496958                       0
# 39                Cosméticos   -193280001.208495                       0
# 40              Farmacêutico    -208257014.19915                       0
# 41         Aluguel de Carros  -1807432634.459543                       0
# 42                   Turismo    -73557408.055094                       0
# 43                       NaN                 NaN                     NaN
# 44                       NaN                 NaN                     NaN
# 45                       NaN                 NaN                     NaN
# 46                       NaN                 NaN                     NaN
# 47                       NaN                 NaN                     NaN
# 48                 Resultado          Variação $                     NaN
# 49                     Subiu  19719227010.141911                     NaN
# 50                   Estável                   0                     NaN
# 51                    Desceu  -6338819961.315349                     NaN
# 52                     Saldo  13380407048.826561                     NaN
# 53                       NaN                 NaN                     NaN
# 54                       NaN                 NaN                     NaN
# 55                       NaN                 NaN                     NaN
# 56  Análise por faixa etária          Variação $  Quantidade de empresas
# 57       Entre 50 e 100 anos   9556228369.675333                      30
# 58          Menos de 50 anos   4026586989.013414                      44
# 59          Mais de 100 anos   -202408309.862189                       7

# %%
df_chatgpt = pd.read_excel('acoes.xlsx',sheet_name='ChatGPT')
df_chatgpt
# Out:
#      Nome da Empresa           Segmento  Idade (em anos)
# 0           Usiminas         Siderurgia               64
# 1      CSN Mineração          Mineração               10
# 2          Petrobras           Petróleo               68
# 3             Suzano   Papel e Celulose               97
# 4       CPFL Energia            Energia              108
# ..               ...                ...              ...
# 73  Carrefour Brasil             Varejo               48
# 74       Casas Bahia             Varejo               64
# 75          Localiza  Aluguel de Carros               50
# 76               CVC            Turismo               49
# 77               GOL   Transporte Aéreo               20
#
# [78 rows x 3 columns]

# %%
df_ticker = pd.read_excel('acoes.xlsx',sheet_name='Ticker')
df_ticker
# Out:
#     Ticker            Nome
# 0    MGLU3  Magazine Luiza
# 1    HAPV3         Hapvida
# 2    PETR4       Petrobras
# 3    B3SA3              B3
# 4    USIM5        Usiminas
# ..     ...             ...
# 530  TKNO3           Tekno
# 531  COCE6          Coelce
# 532  MGEL3         Mangels
# 533  CTSA8      Santanense
# 534  MMAQ4   Minasmáquinas
#
# [535 rows x 2 columns]

# %%
df_principal = df_principal[['Ativo', 'Data', 'Último (R$)', 'Var. Dia (%)']].copy()
df_principal
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)
# 0   USIM5 2024-01-26         9.50          5.20
# 1   CMIN3 2024-01-26         6.82          2.40
# 2   PETR3 2024-01-26        41.96          2.19
# 3   SUZB3 2024-01-26        52.91          2.04
# 4   CPFE3 2024-01-26        37.10          2.03
# ..    ...        ...          ...           ...
# 76  CRFB3 2024-01-26        10.71         -2.45
# 77  BHIA3 2024-01-26         8.70         -2.46
# 78  RENT3 2024-01-26        56.24         -3.63
# 79  CVCB3 2024-01-26         3.07         -4.36
# 80  GOLL4 2024-01-26         5.92         -8.07
#
# [81 rows x 4 columns]

# %%
df_principal = df_principal.rename(columns={'Último (R$)':'valor_final','Var. Dia (%)':'var_dia_pct'}).copy()
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct
# 0   USIM5 2024-01-26         9.50         5.20
# 1   CMIN3 2024-01-26         6.82         2.40
# 2   PETR3 2024-01-26        41.96         2.19
# 3   SUZB3 2024-01-26        52.91         2.04
# 4   CPFE3 2024-01-26        37.10         2.03
# ..    ...        ...          ...          ...
# 76  CRFB3 2024-01-26        10.71        -2.45
# 77  BHIA3 2024-01-26         8.70        -2.46
# 78  RENT3 2024-01-26        56.24        -3.63
# 79  CVCB3 2024-01-26         3.07        -4.36
# 80  GOLL4 2024-01-26         5.92        -8.07
#
# [81 rows x 4 columns]

# %%
df_principal['Var_pct'] = df_principal['var_dia_pct'] / 100
df_principal['Valor_inicial'] = df_principal['valor_final'] / (df_principal['Var_pct'] + 1)
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  Valor_inicial
# 0   USIM5 2024-01-26         9.50         5.20   0.0520       9.030418
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240       6.660156
# 2   PETR3 2024-01-26        41.96         2.19   0.0219      41.060769
# 3   SUZB3 2024-01-26        52.91         2.04   0.0204      51.852215
# 4   CPFE3 2024-01-26        37.10         2.03   0.0203      36.361854
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45  -0.0245      10.978985
# 77  BHIA3 2024-01-26         8.70        -2.46  -0.0246       8.919418
# 78  RENT3 2024-01-26        56.24        -3.63  -0.0363      58.358410
# 79  CVCB3 2024-01-26         3.07        -4.36  -0.0436       3.209954
# 80  GOLL4 2024-01-26         5.92        -8.07  -0.0807       6.439682
#
# [81 rows x 6 columns]

# %%
df_principal = df_principal.merge(df_total_de_acoes, left_on = 'Ativo', right_on = 'Código', how = 'left')
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  Valor_inicial Código  \
# 0   USIM5 2024-01-26         9.50         5.20   0.0520       9.030418  USIM5
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240       6.660156  CMIN3
# 2   PETR3 2024-01-26        41.96         2.19   0.0219      41.060769  PETR3
# 3   SUZB3 2024-01-26        52.91         2.04   0.0204      51.852215  SUZB3
# 4   CPFE3 2024-01-26        37.10         2.03   0.0203      36.361854  CPFE3
# ..    ...        ...          ...          ...      ...            ...    ...
# 76  CRFB3 2024-01-26        10.71        -2.45  -0.0245      10.978985  CRFB3
# 77  BHIA3 2024-01-26         8.70        -2.46  -0.0246       8.919418  BHIA3
# 78  RENT3 2024-01-26        56.24        -3.63  -0.0363      58.358410  RENT3
# 79  CVCB3 2024-01-26         3.07        -4.36  -0.0436       3.209954  CVCB3
# 80  GOLL4 2024-01-26         5.92        -8.07  -0.0807       6.439682  GOLL4
#
#     Qtde. Teórica
# 0    5.151174e+08
# 1    1.110559e+09
# 2    2.379878e+09
# 3    6.834528e+08
# 4    1.877325e+08
# ..            ...
# 76   5.339906e+08
# 77   9.484305e+07
# 78   8.532023e+08
# 79   5.255828e+08
# 80   1.981849e+08
#
# [81 rows x 8 columns]

# %%
df_principal = df_principal.drop(columns=['Código'])
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20   0.0520       9.030418
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240       6.660156
# 2   PETR3 2024-01-26        41.96         2.19   0.0219      41.060769
# 3   SUZB3 2024-01-26        52.91         2.04   0.0204      51.852215
# 4   CPFE3 2024-01-26        37.10         2.03   0.0203      36.361854
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45  -0.0245      10.978985
# 77  BHIA3 2024-01-26         8.70        -2.46  -0.0246       8.919418
# 78  RENT3 2024-01-26        56.24        -3.63  -0.0363      58.358410
# 79  CVCB3 2024-01-26         3.07        -4.36  -0.0436       3.209954
# 80  GOLL4 2024-01-26         5.92        -8.07  -0.0807       6.439682
#
#     Qtde. Teórica
# 0    5.151174e+08
# 1    1.110559e+09
# 2    2.379878e+09
# 3    6.834528e+08
# 4    1.877325e+08
# ..            ...
# 76   5.339906e+08
# 77   9.484305e+07
# 78   8.532023e+08
# 79   5.255828e+08
# 80   1.981849e+08
#
# [81 rows x 7 columns]

# %%
df_principal['Variacao_rs'] = (df_principal['valor_final'] - df_principal['Valor_inicial']) * df_principal['Qtde. Teórica']
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20   0.0520       9.030418
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240       6.660156
# 2   PETR3 2024-01-26        41.96         2.19   0.0219      41.060769
# 3   SUZB3 2024-01-26        52.91         2.04   0.0204      51.852215
# 4   CPFE3 2024-01-26        37.10         2.03   0.0203      36.361854
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45  -0.0245      10.978985
# 77  BHIA3 2024-01-26         8.70        -2.46  -0.0246       8.919418
# 78  RENT3 2024-01-26        56.24        -3.63  -0.0363      58.358410
# 79  CVCB3 2024-01-26         3.07        -4.36  -0.0436       3.209954
# 80  GOLL4 2024-01-26         5.92        -8.07  -0.0807       6.439682
#
#     Qtde. Teórica   Variacao_rs
# 0    5.151174e+08  2.418897e+08
# 1    1.110559e+09  1.775160e+08
# 2    2.379878e+09  2.140059e+09
# 3    6.834528e+08  7.229463e+08
# 4    1.877325e+08  1.385740e+08
# ..            ...           ...
# 76   5.339906e+08 -1.436355e+08
# 77   9.484305e+07 -2.081024e+07
# 78   8.532023e+08 -1.807433e+09
# 79   5.255828e+08 -7.355741e+07
# 80   1.981849e+08 -1.029932e+08
#
# [81 rows x 8 columns]

# %%
pd.options.display.float_format = '{:.2f}'.format
df_principal['Qtde. Teórica'] = df_principal['Qtde. Teórica'].astype(int)

# %%
df_principal = df_principal.rename(columns={'Qtde. Teórica':'qtde_teorica'}).copy()
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     qtde_teorica    Variacao_rs
# 0      515117391   241889725.43
# 1     1110559345   177515970.30
# 2    -2147483648  2140059393.53
# 3      683452836   722946282.71
# 4      187732538   138573955.06
# ..           ...            ...
# 76     533990587  -143635530.57
# 77      94843047   -20810240.84
# 78     853202347 -1807432634.46
# 79     525582771   -73557408.06
# 80     198184909  -102993202.62
#
# [81 rows x 8 columns]

# %%
df_principal['Resultado'] = df_principal['Variacao_rs'].apply(lambda x: 'Subiu' if x > 0 else ('Desceu' if x < 0 else 'Estável'))
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     qtde_teorica    Variacao_rs Resultado
# 0      515117391   241889725.43     Subiu
# 1     1110559345   177515970.30     Subiu
# 2    -2147483648  2140059393.53     Subiu
# 3      683452836   722946282.71     Subiu
# 4      187732538   138573955.06     Subiu
# ..           ...            ...       ...
# 76     533990587  -143635530.57    Desceu
# 77      94843047   -20810240.84    Desceu
# 78     853202347 -1807432634.46    Desceu
# 79     525582771   -73557408.06    Desceu
# 80     198184909  -102993202.62    Desceu
#
# [81 rows x 9 columns]

# %%
df_principal = df_principal.merge(df_ticker, left_on = 'Ativo', right_on = 'Ticker', how = 'left')
df_principal = df_principal.drop(columns=['Ticker'])
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     qtde_teorica    Variacao_rs Resultado              Nome
# 0      515117391   241889725.43     Subiu          Usiminas
# 1     1110559345   177515970.30     Subiu     CSN Mineração
# 2    -2147483648  2140059393.53     Subiu         Petrobras
# 3      683452836   722946282.71     Subiu            Suzano
# 4      187732538   138573955.06     Subiu      CPFL Energia
# ..           ...            ...       ...               ...
# 76     533990587  -143635530.57    Desceu  Carrefour Brasil
# 77      94843047   -20810240.84    Desceu       Casas Bahia
# 78     853202347 -1807432634.46    Desceu          Localiza
# 79     525582771   -73557408.06    Desceu               CVC
# 80     198184909  -102993202.62    Desceu               GOL
#
# [81 rows x 10 columns]

# %%
df_principal = df_principal.merge(df_chatgpt, left_on = 'Nome', right_on = 'Nome da Empresa', how = 'left')
df_principal = df_principal.drop(columns=['Nome da Empresa'])
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     qtde_teorica    Variacao_rs Resultado              Nome  \
# 0      515117391   241889725.43     Subiu          Usiminas
# 1     1110559345   177515970.30     Subiu     CSN Mineração
# 2    -2147483648  2140059393.53     Subiu         Petrobras
# 3      683452836   722946282.71     Subiu            Suzano
# 4      187732538   138573955.06     Subiu      CPFL Energia
# ..           ...            ...       ...               ...
# 76     533990587  -143635530.57    Desceu  Carrefour Brasil
# 77      94843047   -20810240.84    Desceu       Casas Bahia
# 78     853202347 -1807432634.46    Desceu          Localiza
# 79     525582771   -73557408.06    Desceu               CVC
# 80     198184909  -102993202.62    Desceu               GOL
#
#              Segmento  Idade (em anos)
# 0          Siderurgia               64
# 1           Mineração               10
# 2            Petróleo               68
# 3    Papel e Celulose               97
# 4             Energia              108
# ..                ...              ...
# 76             Varejo               48
# 77             Varejo               64
# 78  Aluguel de Carros               50
# 79            Turismo               49
# 80   Transporte Aéreo               20
#
# [81 rows x 12 columns]

# %%
df_principal = df_principal.rename(columns={'Idade (em anos)':'idade_anos'}).copy()
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     qtde_teorica    Variacao_rs Resultado              Nome  \
# 0      515117391   241889725.43     Subiu          Usiminas
# 1     1110559345   177515970.30     Subiu     CSN Mineração
# 2    -2147483648  2140059393.53     Subiu         Petrobras
# 3      683452836   722946282.71     Subiu            Suzano
# 4      187732538   138573955.06     Subiu      CPFL Energia
# ..           ...            ...       ...               ...
# 76     533990587  -143635530.57    Desceu  Carrefour Brasil
# 77      94843047   -20810240.84    Desceu       Casas Bahia
# 78     853202347 -1807432634.46    Desceu          Localiza
# 79     525582771   -73557408.06    Desceu               CVC
# 80     198184909  -102993202.62    Desceu               GOL
#
#              Segmento  idade_anos
# 0          Siderurgia          64
# 1           Mineração          10
# 2            Petróleo          68
# 3    Papel e Celulose          97
# 4             Energia         108
# ..                ...         ...
# 76             Varejo          48
# 77             Varejo          64
# 78  Aluguel de Carros          50
# 79            Turismo          49
# 80   Transporte Aéreo          20
#
# [81 rows x 12 columns]

# %%
df_principal['cat_idade'] = df_principal['idade_anos'].apply(lambda x: 'Mais de 100 anos' if x > 100 else( 'Menos de 50 anos' if x < 50 else "Entre 50 e 100 anos"))
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     qtde_teorica    Variacao_rs Resultado              Nome  \
# 0      515117391   241889725.43     Subiu          Usiminas
# 1     1110559345   177515970.30     Subiu     CSN Mineração
# 2    -2147483648  2140059393.53     Subiu         Petrobras
# 3      683452836   722946282.71     Subiu            Suzano
# 4      187732538   138573955.06     Subiu      CPFL Energia
# ..           ...            ...       ...               ...
# 76     533990587  -143635530.57    Desceu  Carrefour Brasil
# 77      94843047   -20810240.84    Desceu       Casas Bahia
# 78     853202347 -1807432634.46    Desceu          Localiza
# 79     525582771   -73557408.06    Desceu               CVC
# 80     198184909  -102993202.62    Desceu               GOL
#
#              Segmento  idade_anos            cat_idade
# 0          Siderurgia          64  Entre 50 e 100 anos
# 1           Mineração          10     Menos de 50 anos
# 2            Petróleo          68  Entre 50 e 100 anos
# 3    Papel e Celulose          97  Entre 50 e 100 anos
# 4             Energia         108     Mais de 100 anos
# ..                ...         ...                  ...
# 76             Varejo          48     Menos de 50 anos
# 77             Varejo          64  Entre 50 e 100 anos
# 78  Aluguel de Carros          50  Entre 50 e 100 anos
# 79            Turismo          49     Menos de 50 anos
# 80   Transporte Aéreo          20     Menos de 50 anos
#
# [81 rows x 13 columns]

# %%
maior = df_principal['Variacao_rs'].max()
menor = df_principal['Variacao_rs'].min()
media = df_principal['Variacao_rs'].mean()
media_subiu = df_principal[df_principal['Resultado'] == 'Subiu']['Variacao_rs'].mean()
media_desceu = df_principal[df_principal['Resultado'] == 'Desceu']['Variacao_rs'].mean()

print(f'Maior:\tR${maior:,.2f}')
print(f'Menor:\tR${menor:,.2f}')
print(f'Média:\tR${media:,.2f}')
print(f'Média de quem subiu:\tR${media_subiu:,.2f}')
print(f'Média de quem desceu:\tR${media_desceu:,.2f}')
# Out:
# Maior:	R$4,762,926,995.25
# Menor:	R$-1,807,432,634.46
# Média:	R$165,190,210.48
# Média de quem subiu:	R$448,164,250.23
# Média de quem desceu:	R$-181,109,141.75

# %%
df_principal_subiu = df_principal[df_principal['Resultado'] == 'Subiu']
df_principal_subiu
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# 5   PRIO3 2024-01-26        45.69         1.98     0.02          44.80
# 6   PETR4 2024-01-26        39.96         1.73     0.02          39.28
# 7   VALE3 2024-01-26        69.50         1.66     0.02          68.37
# 8   MULT3 2024-01-26        28.19         1.58     0.02          27.75
# 9   ITUB4 2024-01-26        32.81         1.48     0.01          32.33
# 10  RDOR3 2024-01-26        27.56         1.43     0.01          27.17
# 11  BRKM5 2024-01-26        18.55         1.42     0.01          18.29
# 12  AZUL4 2024-01-26        14.27         1.42     0.01          14.07
# 13  RRRP3 2024-01-26        28.75         1.41     0.01          28.35
# 14  EQTL3 2024-01-26        35.32         1.34     0.01          34.85
# 15  CSNA3 2024-01-26        18.16         1.33     0.01          17.92
# 16  YDUQ3 2024-01-26        19.77         1.28     0.01          19.52
# 17  UGPA3 2024-01-26        28.31         1.28     0.01          27.95
# 18  MRVE3 2024-01-26         8.08         1.25     0.01           7.98
# 19  ARZZ3 2024-01-26        57.91         1.15     0.01          57.25
# 20  BBDC4 2024-01-26        15.52         1.04     0.01          15.36
# 21  BEEF3 2024-01-26         7.19         0.98     0.01           7.12
# 22  PCAR3 2024-01-26         4.14         0.97     0.01           4.10
# 23  BRFS3 2024-01-26        14.61         0.96     0.01          14.47
# 24  VIVT3 2024-01-26        51.20         0.88     0.01          50.75
# 25  RAIL3 2024-01-26        22.64         0.84     0.01          22.45
# 26  CIEL3 2024-01-26         4.90         0.82     0.01           4.86
# 27  DXCO3 2024-01-26         7.81         0.77     0.01           7.75
# 28  TIMS3 2024-01-26        17.52         0.74     0.01          17.39
# 29  BRAP4 2024-01-26        23.22         0.73     0.01          23.05
# 30  LWSA3 2024-01-26         5.55         0.72     0.01           5.51
# 31  RECV3 2024-01-26        23.83         0.71     0.01          23.66
# 32  ITSA4 2024-01-26        10.01         0.70     0.01           9.94
# 33  BBAS3 2024-01-26        56.97         0.68     0.01          56.59
# 34  RADL3 2024-01-26        26.16         0.61     0.01          26.00
# 35  GOAU4 2024-01-26        10.08         0.59     0.01          10.02
# 36  CSAN3 2024-01-26        18.57         0.59     0.01          18.46
# 37  JBSS3 2024-01-26        24.34         0.57     0.01          24.20
# 38  MGLU3 2024-01-26         2.08         0.48     0.00           2.07
# 39  BBDC3 2024-01-26        13.75         0.36     0.00          13.70
# 40  GGBR4 2024-01-26        21.84         0.27     0.00          21.78
# 41  RAIZ4 2024-01-26         3.74         0.26     0.00           3.73
# 42  CPLE6 2024-01-26        10.07         0.19     0.00          10.05
# 43  VAMO3 2024-01-26         8.18         0.12     0.00           8.17
#
#     qtde_teorica   Variacao_rs Resultado                  Nome  \
# 0      515117391  241889725.43     Subiu              Usiminas
# 1     1110559345  177515970.30     Subiu         CSN Mineração
# 2    -2147483648 2140059393.53     Subiu             Petrobras
# 3      683452836  722946282.71     Subiu                Suzano
# 4      187732538  138573955.06     Subiu          CPFL Energia
# 5      800010734  709687498.18     Subiu              PetroRio
# 6    -2147483648 3103136291.22     Subiu             Petrobras
# 7    -2147483648 4762926995.25     Subiu                  Vale
# 8      268505432  117732680.08     Subiu             Multiplan
# 9    -2147483648 2297591984.33     Subiu         Itaú Unibanco
# 10    1168230366  453917907.01     Subiu             Rede D'Or
# 11     265877867   69054317.64     Subiu               Braskem
# 12     327593725   65452205.55     Subiu                  Azul
# 13     235665566   94204643.35     Subiu          3R Petroleum
# 14    1095587251  511671895.45     Subiu    Equatorial Energia
# 15     600865451  143220991.46     Subiu  Siderúrgica Nacional
# 16     289347914   72295838.99     Subiu                 YDUQS
# 17    1086411192  388705223.96     Subiu              Ultrapar
# 18     376187582   37525872.38     Subiu                   MRV
# 19      62305891   41021792.09     Subiu                Arezzo
# 20   -2147483648  822148336.41     Subiu        Banco Bradesco
# 21     261036182   18214628.10     Subiu               Minerva
# 22     159430826    6340916.22     Subiu   Grupo Pão de Açúcar
# 23    1677525446  233045769.57     Subiu                   BRF
# 24     423091712  188965307.06     Subiu                  Vivo
# 25    1218352541  229771333.63     Subiu                  Rumo
# 26    1095462329   43657683.38     Subiu                 Cielo
# 27     302768240   18068446.61     Subiu                 Dexco
# 28     807896814  103972807.37     Subiu                   TIM
# 29     251003438   42238249.54     Subiu             Bradespar
# 30     393173139   15598886.65     Subiu               Locaweb
# 31     275005663   46201006.00     Subiu        PetroRecôncavo
# 32   -2147483648  373853994.88     Subiu                Itaúsa
# 33    1420949112  546752087.99     Subiu       Banco do Brasil
# 34    1275798515  202352473.74     Subiu          RaiaDrogasil
# 35     660411219   39045606.94     Subiu    Metalúrgica Gerdau
# 36    1168097881  127229653.18     Subiu                 Cosan
# 37    1134986472  156573285.43     Subiu                   JBS
# 38   -2147483648   28493619.27     Subiu        Magazine Luiza
# 39    1500728902   74019610.05     Subiu        Banco Bradesco
# 40    1118525506   65779607.10     Subiu                Gerdau
# 41    1193047233   11571106.42     Subiu                Raízen
# 42    1679335290   32069789.50     Subiu                 Copel
# 43     421383330    4131341.16     Subiu           Grupo Vamos
#
#                 Segmento  idade_anos            cat_idade
# 0             Siderurgia          64  Entre 50 e 100 anos
# 1              Mineração          10     Menos de 50 anos
# 2               Petróleo          68  Entre 50 e 100 anos
# 3       Papel e Celulose          97  Entre 50 e 100 anos
# 4                Energia         108     Mais de 100 anos
# 5               Petróleo          12     Menos de 50 anos
# 6               Petróleo          68  Entre 50 e 100 anos
# 7              Mineração          78  Entre 50 e 100 anos
# 8       Shopping Centers          47     Menos de 50 anos
# 9   Serviços Financeiros          13     Menos de 50 anos
# 10                 Saúde          47     Menos de 50 anos
# 11          Petroquímica          49     Menos de 50 anos
# 12      Transporte Aéreo          14     Menos de 50 anos
# 13              Petróleo           6     Menos de 50 anos
# 14               Energia          24     Menos de 50 anos
# 15            Siderurgia          78  Entre 50 e 100 anos
# 16              Educação          55  Entre 50 e 100 anos
# 17               Química          84  Entre 50 e 100 anos
# 18      Construção Civil          41     Menos de 50 anos
# 19              Calçados          50  Entre 50 e 100 anos
# 20  Serviços Financeiros          79  Entre 50 e 100 anos
# 21             Alimentos          28     Menos de 50 anos
# 22    Varejo Alimentício          71  Entre 50 e 100 anos
# 23             Alimentos          13     Menos de 50 anos
# 24      Telecomunicações          23     Menos de 50 anos
# 25             Logística           6     Menos de 50 anos
# 26  Serviços Financeiros          12     Menos de 50 anos
# 27            Tecnologia           5     Menos de 50 anos
# 28      Telecomunicações          26     Menos de 50 anos
# 29               Holding          20     Menos de 50 anos
# 30            Tecnologia          23     Menos de 50 anos
# 31              Petróleo           8     Menos de 50 anos
# 32               Holding          54  Entre 50 e 100 anos
# 33  Serviços Financeiros         212     Mais de 100 anos
# 34   Varejo Farmacêutico         118     Mais de 100 anos
# 35            Siderurgia         120     Mais de 100 anos
# 36               Energia          17     Menos de 50 anos
# 37             Alimentos          68  Entre 50 e 100 anos
# 38                Varejo          64  Entre 50 e 100 anos
# 39  Serviços Financeiros          79  Entre 50 e 100 anos
# 40            Siderurgia         120     Mais de 100 anos
# 41               Energia           9     Menos de 50 anos
# 42               Energia          65  Entre 50 e 100 anos
# 43             Logística           7     Menos de 50 anos

# %%
df_analise_segmento = df_principal_subiu.groupby('Segmento')['Variacao_rs'].sum().reset_index()
df_analise_segmento
# Out:
#                 Segmento   Variacao_rs
# 0              Alimentos  407833683.09
# 1               Calçados   41021792.09
# 2       Construção Civil   37525872.38
# 3               Educação   72295838.99
# 4                Energia  821116399.61
# 5                Holding  416092244.42
# 6              Logística  233902674.79
# 7              Mineração 4940442965.55
# 8       Papel e Celulose  722946282.71
# 9           Petroquímica   69054317.64
# 10              Petróleo 6093288832.26
# 11               Química  388705223.96
# 12                 Saúde  453917907.01
# 13  Serviços Financeiros 3784169702.16
# 14      Shopping Centers  117732680.08
# 15            Siderurgia  489935930.93
# 16            Tecnologia   33667333.26
# 17      Telecomunicações  292938114.42
# 18      Transporte Aéreo   65452205.55
# 19                Varejo   28493619.27
# 20    Varejo Alimentício    6340916.22
# 21   Varejo Farmacêutico  202352473.74

# %%
df_analise_saldo = df_principal.groupby('Resultado')['Variacao_rs'].sum().reset_index()
df_analise_saldo
# Out:
#   Resultado    Variacao_rs
# 0    Desceu -6338819961.32
# 1   Estável           0.00
# 2     Subiu 19719227010.14

# %%
fig = px.bar(df_analise_saldo, x='Resultado', y='Variacao_rs', text='Variacao_rs', title='Variação em reais x Resultado')
fig.show()
